# %%
import io
import icu
import json
import HanComparator
import pywikibot

with io.open("rawdata/kangxi-radicals-compat.json", "r", encoding = "utf-8") as r:
    radicals = json.loads(r.read())
    r.close()
with io.open("data/sortkey-rev.json", "r", encoding = "utf-8") as s:
    sortkeys = json.loads(s.read())
    s.close()

# preloaded data
multiples = [
    '㚇', '䁀', '䍇', '䧹', '丬', '亀', '初', '勗', '卤', '卿',
    '唾', '囊', '垂', '捶', '斉', '欽', '歯', '氽', '渠', '牢',
    '着', '竜', '耆', '辶', '迸', '遷', '靖', '黄', '齐', '龽',
    '鿂', '着', '靖', '𠁣', '𠁤', '𠂙', '𠃛', '𠎤', '𠔾', '𡙶',
    '𢆡', '𢘅', '𣯡', '𤄯', '𤏲', '𤓰', '𤮖', '𥉩', '𥪝', '𥪞',
    '𧢛', '𪁠', '𪥛', '𪪩', '𪱯', '𪷹', '𪽞', '𪿁', '𫏽', '𫠠',
    '𫡏', '𫣙', '𫣚', '𬂀', '𬂙', '𬔔', '𬺱', '𬼉', '𭠍', '𮄿',
    '灰'
]
normalPUAs = [
    0xFA0E, 0xFA0F, 0xFA11, 0xFA13, 0xFA14, 0xFA1F,
    0xFA21, 0xFA23, 0xFA24, 0xFA27, 0xFA28, 0xFA29
]

comp = HanComparator.HanComparator()
site = pywikibot.Site("th", "wiktionary", "OctraBot")

length = len(radicals["original"])
for index in range(length):
    radical = radicals["original"][index]
    radicalAlt = radicals["alternative"][index]
    index += 1

    buffer = "{{สารบัญดัชนีอักษรจีน}}\nข้อมูลอักษรจีนจากยูนิฮัน โดยยูนิโคดรุ่น 14.0.0 รายการหลักเรียงตามจำนวนขีดที่เพิ่มขึ้น \
รายการย่อยเรียงตามบล็อก CJK และ CJK ส่วนขยาย A-G อุปกรณ์ของท่านอาจแสดงผลได้ไม่ครบทุกตัวอักษร \
รายการเหล่านี้สร้างขึ้นด้วยบอต ไม่ควรแก้ไขด้วยมือ \n\nเครื่องหมาย ⁕ คือตัวอักษรที่มีการจัดหมวดได้มากกว่าหนึ่งแบบ __NOTOC__\n\n"
    buffer += "== {} (รากอักษรจีนที่ {}) ==\n\n".format(radical, index)

    for stroke in range(-10, 90):
        sortkey = radical + "{:+03d}".format(stroke).replace("+", "")
        sortkeyAlt = radicalAlt + "{:+03d}".format(stroke).replace("+", "")
        
        if sortkey in sortkeys and sortkeyAlt in sortkeys:
            if radical == radicalAlt:
                hanList = sortkeys[sortkey]
            else:
                hanList = list(set(sortkeys[sortkey] + sortkeys[sortkeyAlt])) # to sort later
        elif sortkey in sortkeys and sortkeyAlt not in sortkeys:
            hanList = sortkeys[sortkey]
        elif sortkey not in sortkeys and sortkeyAlt in sortkeys:
            hanList = sortkeys[sortkeyAlt]
        else:
            hanList = []
        
        if len(hanList) > 0:
            marklist = ""
            for hanChar in hanList[:]:
                # compatibility chars result in duplicated chars on web, so remove them
                blockID = icu.Char.ublock_getCode(hanChar)
                if blockID == getattr(icu.UBlockCode, "CJK_COMPATIBILITY_IDEOGRAPHS") \
                    or blockID == getattr(icu.UBlockCode, "CJK_COMPATIBILITY_IDEOGRAPHS_SUPPLEMENT"):
                    if ord(hanChar) not in normalPUAs:
                        hanList.remove(hanChar)
                if hanChar in multiples:
                    marklist += hanChar

            buffer += "=== {:+d} ขีด ===\n\n".format(stroke).replace("-", "−") # true minus
            buffer += "{{charlist|sc=Hani|"
            hanList.sort(key = comp.getCollationKey)
            buffer += "".join(hanList)
            if marklist != "":
                buffer += "|marklist=" + marklist
            buffer += "}}\n\n"

    pagename = "ดัชนี:รากอักษรจีน/" + radical
    page = pywikibot.Page(site, pagename)
    page.text = buffer
    page.save("updated")
# Out:
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/一]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:19:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/丨]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:19:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/丶]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:19:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/丿]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:19:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/乙]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:19:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/亅]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:19:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/二]] saved
# Sleeping for 8.8 seconds, 2022-07-16 23:20:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/亠]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:20:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/人]] saved
# Sleeping for 7.7 seconds, 2022-07-16 23:20:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/儿]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:20:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/入]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:20:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/八]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:20:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/冂]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:21:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/冖]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:21:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/冫]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:21:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/几]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:21:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/凵]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:21:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/刀]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:21:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/力]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:22:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/勹]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:22:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/匕]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:22:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/匚]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:22:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/匸]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:22:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/十]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:22:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/卜]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:23:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/卩]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:23:15
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/厂]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:23:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/厶]] saved
# Sleeping for 8.8 seconds, 2022-07-16 23:23:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/又]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:23:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/口]] saved
# Sleeping for 7.8 seconds, 2022-07-16 23:23:56
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/囗]] saved
# Sleeping for 8.3 seconds, 2022-07-16 23:24:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/土]] saved
# Sleeping for 8.3 seconds, 2022-07-16 23:24:16
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/士]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:24:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/夂]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:24:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/夊]] saved
# Sleeping for 7.4 seconds, 2022-07-16 23:24:46
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/夕]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:24:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/大]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:25:06
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/女]] saved
# Sleeping for 8.1 seconds, 2022-07-16 23:25:16
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/子]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:25:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/宀]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:25:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/寸]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:25:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/小]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:25:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/尢]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:26:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/尸]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:26:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/屮]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:26:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/山]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:26:36
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/巛]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:26:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/工]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:26:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/己]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:27:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/巾]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:27:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/干]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:27:25
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/幺]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:27:35
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/广]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:27:45
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/廴]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:27:55
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/廾]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:28:05
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/弋]] saved
# Sleeping for 8.8 seconds, 2022-07-16 23:28:15
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/弓]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/目]] saved
# Sleeping for 8.1 seconds, 2022-07-16 23:37:07
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/矛]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:37:16
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/矢]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:37:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/石]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:37:36
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/示]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:37:46
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/禸]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:37:56
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/禾]] saved
# Sleeping for 8.3 seconds, 2022-07-16 23:38:06
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/穴]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:38:16
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/立]] saved
# Sleeping for 8.2 seconds, 2022-07-16 23:38:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/竹]] saved
# Sleeping for 8.2 seconds, 2022-07-16 23:38:37
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/米]] saved
# Sleeping for 8.2 seconds, 2022-07-16 23:38:47
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/糸]] saved
# Sleeping for 7.9 seconds, 2022-07-16 23:38:57
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/缶]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:39:06
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/网]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:39:16
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/羊]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:39:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/羽]] saved
# Sleeping for 8.1 seconds, 2022-07-16 23:39:37
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/老]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:39:46
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/而]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:39:56
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/耒]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:40:06
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/耳]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:40:16
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/聿]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:40:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/肉]] saved
# Sleeping for 8.1 seconds, 2022-07-16 23:40:37
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/臣]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:40:46
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/自]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:40:56
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/至]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:41:06
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/臼]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:41:16
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/舌]] saved
# Sleeping for 8.7 seconds, 2022-07-16 23:41:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/舛]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:41:36
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/舟]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:41:46
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/艮]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:41:56
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/色]] saved
# Sleeping for 8.0 seconds, 2022-07-16 23:42:07
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/艸]] saved
# Sleeping for 7.6 seconds, 2022-07-16 23:42:17
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/虍]] saved
# Sleeping for 8.1 seconds, 2022-07-16 23:42:27
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/虫]] saved
# Sleeping for 8.2 seconds, 2022-07-16 23:42:37
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/血]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:42:46
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/行]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:42:57
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/衣]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:43:07
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/襾]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:43:16
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/見]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:43:26
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/角]] saved
# Sleeping for 8.3 seconds, 2022-07-16 23:43:37
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/言]] saved
# Sleeping for 8.2 seconds, 2022-07-16 23:43:47
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/谷]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:43:56
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/豆]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:44:06
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/豕]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:44:17
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/豸]] saved
# Sleeping for 8.5 seconds, 2022-07-16 23:44:27
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/貝]] saved
# Sleeping for 8.4 seconds, 2022-07-16 23:44:37
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/赤]] saved
# Sleeping for 8.6 seconds, 2022-07-16 23:44:47
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน/走]] saved
# Sleeping for 8.1 seconds, 2022-07-16 23:44:57
# Page [[wiktionary:th:ดัชนี:รากอักษรจีน
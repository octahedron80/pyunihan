# %%
import io
import icu
import json
import HanComparator
import pywikibot

with io.open("rawdata/kangxi-radicals-compat.json", "r", encoding = "utf-8") as r:
    radicals = json.loads(r.read())
with io.open("data/sortkey-rev.json", "r", encoding = "utf-8") as s:
    sortkeys = json.loads(s.read())

# preloaded data
multiples = [
    '㚇', '䁀', '䍇', '䧹', '丬', '亀', '初', '勗', '卤', '卿',
    '唾', '囊', '垂', '捶', '斉', '欽', '歯', '氽', '渠', '牢',
    '着', '竜', '耆', '辶', '迸', '遷', '靖', '黄', '齐', '龽',
    '鿂', '着', '靖', '𠁣', '𠁤', '𠂙', '𠃛', '𠎤', '𠔾', '𡙶',
    '𢆡', '𢘅', '𣯡', '𤄯', '𤏲', '𤓰', '𤮖', '𥉩', '𥪝', '𥪞',
    '𧢛', '𪁠', '𪥛', '𪪩', '𪱯', '𪷹', '𪽞', '𪿁', '𫏽', '𫠠',
    '𫡏', '𫣙', '𫣚', '𬂀', '𬂙', '𬔔', '𬺱', '𬼉', '𭠍', '𮄿',
    '灰'
]
normalPUAs = [
    0xFA0E, 0xFA0F, 0xFA11, 0xFA13, 0xFA14, 0xFA1F,
    0xFA21, 0xFA23, 0xFA24, 0xFA27, 0xFA28, 0xFA29
]

comp = HanComparator.HanComparator()
site = pywikibot.Site("th", "wiktionary", "OctraBot")

length = len(radicals["original"])
for index in range(length):
    radical = radicals["original"][index]
    radicalAlt = radicals["alternative"][index]
    index += 1

    buffer = "{{สารบัญดัชนีอักษรจีน}}\nข้อมูลอักษรจีนจากยูนิฮัน โดยยูนิโคดรุ่น 15.0.0 รายการหลักเรียงตามจำนวนขีดที่เพิ่มขึ้น \
รายการย่อยเรียงตามบล็อก CJK และ CJK ส่วนขยาย A-H อุปกรณ์ของท่านอาจแสดงผลได้ไม่ครบทุกตัวอักษร \
รายการเหล่านี้สร้างขึ้นด้วยบอต ไม่ควรแก้ไขด้วยมือ \n\nเครื่องหมาย ⁕ คือตัวอักษรที่มีการจัดหมวดได้มากกว่าหนึ่งแบบ __NOTOC__\n\n"
    buffer += "== {} (รากอักษรจีนที่ {}) ==\n\n".format(radical, index)

    for stroke in range(-10, 90):
        sortkey = radical + "{:+03d}".format(stroke).replace("+", "")
        sortkeyAlt = radicalAlt + "{:+03d}".format(stroke).replace("+", "")
        
        if sortkey in sortkeys and sortkeyAlt in sortkeys:
            if radical == radicalAlt:
                hanList = sortkeys[sortkey]
            else:
                hanList = list(set(sortkeys[sortkey] + sortkeys[sortkeyAlt])) # to sort later
        elif sortkey in sortkeys and sortkeyAlt not in sortkeys:
            hanList = sortkeys[sortkey]
        elif sortkey not in sortkeys and sortkeyAlt in sortkeys:
            hanList = sortkeys[sortkeyAlt]
        else:
            hanList = []
        
        if len(hanList) > 0:
            marklist = ""
            for hanChar in hanList[:]:
                # compatibility chars result in duplicated chars on web, so remove them
                blockID = icu.Char.ublock_getCode(hanChar)
                if blockID == getattr(icu.UBlockCode, "CJK_COMPATIBILITY_IDEOGRAPHS") \
                    or blockID == getattr(icu.UBlockCode, "CJK_COMPATIBILITY_IDEOGRAPHS_SUPPLEMENT"):
                    if ord(hanChar) not in normalPUAs:
                        hanList.remove(hanChar)
                if hanChar in multiples:
                    marklist += hanChar

            buffer += "=== {:+d} ขีด ===\n\n".format(stroke).replace("-", "−") # true minus
            buffer += "{{charlist|sep=、|sc=Hani|"
            hanList.sort(key = comp.getCollationKey)
            buffer += "".join(hanList)
            if marklist != "":
                buffer += "|marklist=" + marklist
            buffer += "}}\n\n"

    pagename = "ดัชนี:รากอักษรจีน/" + radical
    page = pywikibot.Page(site, pagename)
    page.text = buffer
    page.save("updated")
# Out:
# Page [[ดัชนี:รากอักษรจีน/一]] saved
# Page [[ดัชนี:รากอักษรจีน/丨]] saved
# Page [[ดัชนี:รากอักษรจีน/丶]] saved
# Page [[ดัชนี:รากอักษรจีน/丿]] saved
# Page [[ดัชนี:รากอักษรจีน/乙]] saved
# Page [[ดัชนี:รากอักษรจีน/亅]] saved
# Page [[ดัชนี:รากอักษรจีน/二]] saved
# Page [[ดัชนี:รากอักษรจีน/亠]] saved
# Page [[ดัชนี:รากอักษรจีน/人]] saved
# Page [[ดัชนี:รากอักษรจีน/儿]] saved
# Page [[ดัชนี:รากอักษรจีน/入]] saved
# Page [[ดัชนี:รากอักษรจีน/八]] saved
# Page [[ดัชนี:รากอักษรจีน/冂]] saved
# Page [[ดัชนี:รากอักษรจีน/冖]] saved
# Page [[ดัชนี:รากอักษรจีน/冫]] saved
# Page [[ดัชนี:รากอักษรจีน/几]] saved
# Page [[ดัชนี:รากอักษรจีน/凵]] saved
# Page [[ดัชนี:รากอักษรจีน/刀]] saved
# Page [[ดัชนี:รากอักษรจีน/力]] saved
# Page [[ดัชนี:รากอักษรจีน/勹]] saved
# Page [[ดัชนี:รากอักษรจีน/匕]] saved
# Page [[ดัชนี:รากอักษรจีน/匚]] saved
# Page [[ดัชนี:รากอักษรจีน/匸]] saved
# Page [[ดัชนี:รากอักษรจีน/十]] saved
# Page [[ดัชนี:รากอักษรจีน/卜]] saved
# Page [[ดัชนี:รากอักษรจีน/卩]] saved
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[ดัชนี:รากอักษรจีน/厂]] saved
# Page [[ดัชนี:รากอักษรจีน/厶]] saved
# Page [[ดัชนี:รากอักษรจีน/又]] saved
# Page [[ดัชนี:รากอักษรจีน/口]] saved
# Page [[ดัชนี:รากอักษรจีน/囗]] saved
# Page [[ดัชนี:รากอักษรจีน/土]] saved
# Page [[ดัชนี:รากอักษรจีน/士]] saved
# Page [[ดัชนี:รากอักษรจีน/夂]] saved
# Page [[ดัชนี:รากอักษรจีน/夊]] saved
# Page [[ดัชนี:รากอักษรจีน/夕]] saved
# Page [[ดัชนี:รากอักษรจีน/大]] saved
# Page [[ดัชนี:รากอักษรจีน/女]] saved
# Page [[ดัชนี:รากอักษรจีน/子]] saved
# Page [[ดัชนี:รากอักษรจีน/宀]] saved
# Page [[ดัชนี:รากอักษรจีน/寸]] saved
# Page [[ดัชนี:รากอักษรจีน/小]] saved
# Page [[ดัชนี:รากอักษรจีน/尢]] saved
# Page [[ดัชนี:รากอักษรจีน/尸]] saved
# Page [[ดัชนี:รากอักษรจีน/屮]] saved
# Page [[ดัชนี:รากอักษรจีน/山]] saved
# Page [[ดัชนี:รากอักษรจีน/巛]] saved
# Page [[ดัชนี:รากอักษรจีน/工]] saved
# Page [[ดัชนี:รากอักษรจีน/己]] saved
# Page [[ดัชนี:รากอักษรจีน/巾]] saved
# Page [[ดัชนี:รากอักษรจีน/干]] saved
# Page [[ดัชนี:รากอักษรจีน/幺]] saved
# Page [[ดัชนี:รากอักษรจีน/广]] saved
# Page [[ดัชนี:รากอักษรจีน/廴]] saved
# Page [[ดัชนี:รากอักษรจีน/廾]] saved
# Page [[ดัชนี:รากอักษรจีน/弋]] saved
# Page [[ดัชนี:รากอักษรจีน/弓]] saved
# Page [[ดัชนี:รากอักษรจีน/彐]] saved
# Page [[ดัชนี:รากอักษรจีน/彡]] saved
# Page [[ดัชนี:รากอักษรจีน/彳]] saved
# Page [[ดัชนี:รากอักษรจีน/心]] saved
# Page [[ดัชนี:รากอักษรจีน/戈]] saved
# Page [[ดัชนี:รากอักษรจีน/戶]] saved
# Page [[ดัชนี:รากอักษรจีน/手]] saved
# Page [[ดัชนี:รากอักษรจีน/支]] saved
# Page [[ดัชนี:รากอักษรจีน/攴]] saved
# Page [[ดัชนี:รากอักษรจีน/文]] saved
# Page [[ดัชนี:รากอักษรจีน/斗]] saved
# Page [[ดัชนี:รากอักษรจีน/斤]] saved
# Page [[ดัชนี:รากอักษรจีน/方]] saved
# Page [[ดัชนี:รากอักษรจีน/无]] saved
# Page [[ดัชนี:รากอักษรจีน/日]] saved
# Page [[ดัชนี:รากอักษรจีน/曰]] saved
# Page [[ดัชนี:รากอักษรจีน/月]] saved
# Page [[ดัชนี:รากอักษรจีน/木]] saved
# Page [[ดัชนี:รากอักษรจีน/欠]] saved
# Page [[ดัชนี:รากอักษรจีน/止]] saved
# Page [[ดัชนี:รากอักษรจีน/歹]] saved
# Page [[ดัชนี:รากอักษรจีน/殳]] saved
# Page [[ดัชนี:รากอักษรจีน/毋]] saved
# Page [[ดัชนี:รากอักษรจีน/比]] saved
# Page [[ดัชนี:รากอักษรจีน/毛]] saved
# Page [[ดัชนี:รากอักษรจีน/氏]] saved
# Page [[ดัชนี:รากอักษรจีน/气]] saved
# Page [[ดัชนี:รากอักษรจีน/水]] saved
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[ดัชนี:รากอักษรจีน/火]] saved
# Page [[ดัชนี:รากอักษรจีน/爪]] saved
# Page [[ดัชนี:รากอักษรจีน/父]] saved
# Page [[ดัชนี:รากอักษรจีน/爻]] saved
# Page [[ดัชนี:รากอักษรจีน/爿]] saved
# Page [[ดัชนี:รากอักษรจีน/片]] saved
# Page [[ดัชนี:รากอักษรจีน/牙]] saved
# Page [[ดัชนี:รากอักษรจีน/牛]] saved
# Page [[ดัชนี:รากอักษรจีน/犬]] saved
# Page [[ดัชนี:รากอักษรจีน/玄]] saved
# Page [[ดัชนี:รากอักษรจีน/玉]] saved
# Page [[ดัชนี:รากอักษรจีน/瓜]] saved
# Page [[ดัชนี:รากอักษรจีน/瓦]] saved
# Page [[ดัชนี:รากอักษรจีน/甘]] saved
# Page [[ดัชนี:รากอักษรจีน/生]] saved
# Page [[ดัชนี:รากอักษรจีน/用]] saved
# Page [[ดัชนี:รากอักษรจีน/田]] saved
# Page [[ดัชนี:รากอักษรจีน/疋]] saved
# Page [[ดัชนี:รากอักษรจีน/疒]] saved
# Page [[ดัชนี:รากอักษรจีน/癶]] saved
# Page [[ดัชนี:รากอักษรจีน/白]] saved
# Page [[ดัชนี:รากอักษรจีน/皮]] saved
# Page [[ดัชนี:รากอักษรจีน/皿]] saved
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[ดัชนี:รากอักษรจีน/目]] saved
# Page [[ดัชนี:รากอักษรจีน/矛]] saved
# Page [[ดัชนี:รากอักษรจีน/矢]] saved
# Page [[ดัชนี:รากอักษรจีน/石]] saved
# Page [[ดัชนี:รากอักษรจีน/示]] saved
# Page [[ดัชนี:รากอักษรจีน/禸]] saved
# Page [[ดัชนี:รากอักษรจีน/禾]] saved
# Page [[ดัชนี:รากอักษรจีน/穴]] saved
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[ดัชนี:รากอักษรจีน/立]] saved
# Page [[ดัชนี:รากอักษรจีน/竹]] saved
# Page [[ดัชนี:รากอักษรจีน/米]] saved
# Page [[ดัชนี:รากอักษรจีน/糸]] saved
# Page [[ดัชนี:รากอักษรจีน/缶]] saved
# Page [[ดัชนี:รากอักษรจีน/网]] saved
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[ดัชนี:รากอักษรจีน/羊]] saved
# Page [[ดัชนี:รากอักษรจีน/羽]] saved
# Page [[ดัชนี:รากอักษรจีน/老]] saved
# Page [[ดัชนี:รากอักษรจีน/而]] saved
# Page [[ดัชนี:รากอักษรจีน/耒]] saved
# Page [[ดัชนี:รากอักษรจีน/耳]] saved
# Page [[ดัชนี:รากอักษรจีน/聿]] saved
# Page [[ดัชนี:รากอักษรจีน/肉]] saved
# Page [[ดัชนี:รากอักษรจีน/臣]] saved
# Page [[ดัชนี:รากอักษรจีน/自]] saved
# Page [[ดัชนี:รากอักษรจีน/至]] saved
# Page [[ดัชนี:รากอักษรจีน/臼]] saved
# Page [[ดัชนี:รากอักษรจีน/舌]] saved
# Page [[ดัชนี:รากอักษรจีน/舛]] saved
# Page [[ดัชนี:รากอักษรจีน/舟]] saved
# Page [[ดัชนี:รากอักษรจีน/艮]] saved
# Page [[ดัชนี:รากอักษรจีน/色]] saved
# Page [[ดัชนี:รากอักษรจีน/艸]] saved
# Page [[ดัชนี:รากอักษรจีน/虍]] saved
# Page [[ดัชนี:รากอักษรจีน/虫]] saved
# Page [[ดัชนี:รากอักษรจีน/血]] saved
# Page [[ดัชนี:รากอักษรจีน/行]] saved
# Page [[ดัชนี:รากอักษรจีน/衣]] saved
# Page [[ดัชนี:รากอักษรจีน/襾]] saved
# Page [[ดัชนี:รากอักษรจีน/見]] saved
# Page [[ดัชนี:รากอักษรจีน/角]] saved
# Page [[ดัชนี:รากอักษรจีน/言]] saved
# Page [[ดัชนี:รากอักษรจีน/谷]] saved
# Page [[ดัชนี:รากอักษรจีน/豆]] saved
# Page [[ดัชนี:รากอักษรจีน/豕]] saved
# Page [[ดัชนี:รากอักษรจีน/豸]] saved
# Page [[ดัชนี:รากอักษรจีน/貝]] saved
# Page [[ดัชนี:รากอักษรจีน/赤]] saved
# Page [[ดัชนี:รากอักษรจีน/走]] saved
# Page [[ดัชนี:รากอักษรจีน/足]] saved
# Page [[ดัชนี:รากอักษรจีน/身]] saved
# Page [[ดัชนี:รากอักษรจีน/車]] saved
# Page [[ดัชนี:รากอักษรจีน/辛]] saved
# Page [[ดัชนี:รากอักษรจีน/辰]] saved
# Page [[ดัชนี:รากอักษรจีน/辵]] saved
# Page [[ดัชนี:รากอักษรจีน/邑]] saved
# Page [[ดัชนี:รากอักษรจีน/酉]] saved
# Page [[ดัชนี:รากอักษรจีน/釆]] saved
# Page [[ดัชนี:รากอักษรจีน/里]] saved
# Page [[ดัชนี:รากอักษรจีน/金]] saved
# Page [[ดัชนี:รากอักษรจีน/長]] saved
# Page [[ดัชนี:รากอักษรจีน/門]] saved
# Page [[ดัชนี:รากอักษรจีน/阜]] saved
# Page [[ดัชนี:รากอักษรจีน/隶]] saved
# Page [[ดัชนี:รากอักษรจีน/隹]] saved
# Page [[ดัชนี:รากอักษรจีน/雨]] saved
# WARNING: API warning (edit): The value passed for "text" contains invalid or non-normalized data. Textual data should be valid, NFC-normalized Unicode without C0 control characters other than HT (\t), LF (\n), and CR (\r).
# Page [[ดัชนี:รากอักษรจีน/靑]] saved
# Page [[ดัชนี:รากอักษรจีน/非]] saved
# Page [[ดัชนี:รากอักษรจีน/面]] saved
# Page [[ดัชนี:รากอักษรจีน/革]] saved
# Page [[ดัชนี:รากอักษรจีน/韋]] saved
# Page [[ดัชนี:รากอักษรจีน/韭]] saved
# Page [[ดัชนี:รากอักษรจีน/音]] saved
# Page [[ดัชนี:รากอักษรจีน/頁]] saved
# Page [[ดัชนี:รากอักษรจีน/風]] saved
# Page [[ดัชนี:รากอักษรจีน/飛]] saved
# Page [[ดัชนี:รากอักษรจีน/食]] saved
# Page [[ดัชนี:รากอักษรจีน/首]] saved
# Page [[ดัชนี:รากอักษรจีน/香]] saved
# Page [[ดัชนี:รากอักษรจีน/馬]] saved
# Page [[ดัชนี:รากอักษรจีน/骨]] saved
# Page [[ดัชนี:รากอักษรจีน/高]] saved
# Page [[ดัชนี:รากอักษรจีน/髟]] saved
# Page [[ดัชนี:รากอักษรจีน/鬥]] saved
# Page [[ดัชนี:รากอักษรจีน/鬯]] saved
# Page [[ดัชนี:รากอักษรจีน/鬲]] saved
# Page [[ดัชนี:รากอักษรจีน/鬼]] saved
# Page [[ดัชนี:รากอักษรจีน/魚]] saved
# Page [[ดัชนี:รากอักษรจีน/鳥]] saved
# Page [[ดัชนี:รากอักษรจีน/鹵]] saved
# Page [[ดัชนี:รากอักษรจีน/鹿]] saved
# Page [[ดัชนี:รากอักษรจีน/麥]] saved
# Page [[ดัชนี:รากอักษรจีน/麻]] saved
# Page [[ดัชนี:รากอักษรจีน/黃]] saved
# Page [[ดัชนี:รากอักษรจีน/黍]] saved
# Page [[ดัชนี:รากอักษรจีน/黑]] saved
# Page [[ดัชนี:รากอักษรจีน/黹]] saved
# Page [[ดัชนี:รากอักษรจีน/黽]] saved
# Page [[ดัชนี:รากอักษรจีน/鼎]] saved
# Page [[ดัชนี:รากอักษรจีน/鼓]] saved
# Page [[ดัชนี:รากอักษรจีน/鼠]] saved
# Page [[ดัชนี:รากอักษรจีน/鼻]] saved
# Page [[ดัชนี:รากอักษรจีน/齊]] saved
# Page [[ดัชนี:รากอักษรจีน/齒]] saved
# Page [[ดัชนี:รากอักษรจีน/龍]] saved
# Page [[ดัชนี:รากอักษรจีน/龜]] saved
# Page [[ดัชนี:รากอักษรจีน/龠]] saved
